# %%
import numpy as np

# %%
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import numpy as np

meu_diretorio = "C:/Users/Hugo/Documents/GitHub/CD/Projeto 1"
os.chdir(meu_diretorio)
dados = pd.read_csv("PES2014.csv")

# %%
aposentados = dados[(dados.V1251 == 1) & (dados.V8005 >50)]

# %%
jovens = dados[(dados.V8005 >= 10) & (dados.V8005 <= 17)]

# %%
adultos = dados[(dados.V8005 >= 35)  & (dados.V8005 < 50)]

# %%
aposentados.V8005.describe()
# Out:
# count    36892.000000
# mean        68.543749
# std          9.206339
# min         51.000000
# 25%         62.000000
# 50%         68.000000
# 75%         74.000000
# max        112.000000
# Name: V8005, dtype: float64

# %%
aposentados.V8005.plot(kind="hist",normed=1)

# %%
aposentados.V8005.plot(kind="box")

# %%
aposentados.V9058.plot(kind="box")

# %%
aposentados.V9921.plot(kind="box")

# %%
aposentados = aposentados[(aposentados.V8005 >= 62) & (aposentados.V8005 <= 74) & (aposentados.V9058 >= 20) & (aposentados.V9058 <= 40) & (aposentados.V9921 >=5) & (aposentados.V9921 <= 20)]

# %%
a = pd.crosstab(aposentados.V8005, aposentados.V9057)
a.plot(kind='bar')

# %%
coluna = aposentados.V9057
colum = aposentados.V9057
coluna = coluna.astype('category')
coluna.cat.categories = ('Até 30 minutos','Entre 30mins e 1hora', " Entre 1 hora até 2 horas","Mais de duas horas")
coluna = coluna.value_counts(True)*100
coluna.plot(kind="pie",colors=("blue","green","red","yellow"))

# %%
print(colum.value_counts())
# Out:
# 1.0    354
# 3.0    128
# 5.0     34
# 7.0      8
# Name: V9057, dtype: int64

# %%
caminho = (354*0.5 + 128*0.75 + 34*1.5 + 8*2)/(354+128+34+8)*2
trampo = np.average(aposentados.V9058/7)
afazeres = np.average(aposentados.V9921/7)

# %%
tempo_livre = 18 - caminho - trampo - afazeres
print(tempo_livre)
# Out:
# 10.4843574808

# %%
aposentados = aposentados[(aposentados.V1252 < 10000) &  (aposentados.V4719 < 30000)]

# %%
aposentados.V4719.plot(kind='box')

# %%
aposentados.V4719.value_counts()
# Out:
# 0.0        299
# 1000.0      59
# 724.0       49
# 2000.0      46
# 300.0       42
# 500.0       41
# 800.0       38
# 400.0       36
# 1200.0      28
# 600.0       24
# 200.0       23
# 1500.0      23
# 700.0       20
# 3000.0      18
# 5000.0      18
# 2500.0      16
# 100.0       16
# 250.0       13
# 900.0       13
# 1300.0      12
# 10000.0      9
# 350.0        9
# 4000.0       9
# 6000.0       8
# 1600.0       8
# 3500.0       8
# 450.0        6
# 150.0        6
# 1400.0       6
# 1800.0       5
#           ...
# 9000.0       1
# 830.0        1
# 2400.0       1
# 1050.0       1
# 2900.0       1
# 1020.0       1
# 1015.0       1
# 990.0        1
# 5040.0       1
# 950.0        1
# 13000.0      1
# 4032.0       1
# 680.0        1
# 1850.0       1
# 4450.0       1
# 6500.0       1
# 980.0        1
# 372.0        1
# 380.0        1
# 5500.0       1
# 420.0        1
# 480.0        1
# 9500.0       1
# 1280.0       1
# 570.0        1
# 583.0        1
# 1250.0       1
# 630.0        1
# 1136.0       1
# 678.0        1
# Name: V4719, dtype: int64

# %%
aposentados.V4719.plot(kind='hist',normed=1)

# %%
aposentados.V1252.plot(kind='hist')

# %%
media = aposentados.V8005.mean()
print((1/media)*100)
# Out:
# 1.4918607047187307

# %%
aposentados = dados[(dados.V1251 == 1) & (dados.V8005 >50)]
aposentados.V4720 = aposentados.V4720[(aposentados.V4720 <50000)]
aposentados.V4720.mean()
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 1922.5233862904122

# %% [markdown]
# # Jovens

# %%
jovens.V4720 = jovens.V4720[(jovens.V4720 < 99999999)]
jovens.V4720.value_counts()
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 0.0        41170
# 724.0        688
# 200.0        452
# 100.0        368
# 300.0        366
# 400.0        334
# 150.0        320
# 500.0        263
# 800.0        186
# 600.0        184
# 250.0        166
# 50.0         164
# 350.0        139
# 1000.0       131
# 362.0         98
# 80.0          97
# 70.0          95
# 120.0         95
# 900.0         93
# 450.0         92
# 700.0         85
# 60.0          73
# 1200.0        70
# 112.0         55
# 75.0          54
# 160.0         46
# 360.0         44
# 130.0         44
# 30.0          44
# 40.0          41
#            ...
# 528.0          1
# 533.0          1
# 1090.0         1
# 552.0          1
# 554.0          1
# 555.0          1
# 566.0          1
# 575.0          1
# 484.0          1
# 475.0          1
# 404.0          1
# 471.0          1
# 406.0          1
# 407.0          1
# 409.0          1
# 412.0          1
# 414.0          1
# 416.0          1
# 419.0          1
# 1125.0         1
# 431.0          1
# 432.0          1
# 436.0          1
# 438.0          1
# 8380.0         1
# 452.0          1
# 454.0          1
# 462.0          1
# 464.0          1
# 15000.0        1
# Name: V4720, dtype: int64

# %%
jovens.V4720 = jovens.V4720[(jovens.V4720 < 99999999) & (jovens.V4720 > 0)]
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
coluna = jovens.V9057
coluna = coluna.astype('category')
coluna.cat.categories = ('Até 30 minutos','Entre 30mins e 1hora', " Entre 1 hora até 2 horas","Mais de duas horas")
coluna = coluna.value_counts(True)*100
coluna.plot(kind="pie",colors=("blue","green","red","yellow"))

# %%
coluna.value_counts()
# Out:
# 15.593129    1
# 4.643049     1
# 0.724638     1
# 79.039184    1
# Name: V9057, dtype: int64

# %%
media_caminho = ((2945*0.5 + 581*0.75 + 173*1.5)*2)/(2945+581+173+41170)
print(((2945*0.5 + 581*0.75 + 173*1.5)*2)/(2945+581+173+41170))
# Out:
# 0.09662573268849317

# %%
jovens.V9058 = jovens.V9058/7
jovens.V9058.plot(kind='box')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
q2_renda = 0.5

# %%
jovens.V9921 = jovens.V9921/7
jovens.V9921.plot(kind='box')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
q2_afazeres = 0.2
print(q2_renda + q2_afazeres + media_caminho)
# Out:
# 0.7966257326884931

# %%
tempo_livre= 12 - (q2_renda + q2_afazeres + media_caminho)
print(tempo_livre)
# Out:
# 11.203374267311506

# %%
jovens = dados[(dados.V8005 >= 10) & (dados.V8005 <= 17) & (dados.V4720 < 99999999)]
jovens.V4720.plot(kind="hist")

# %%
jovens.V4720 = jovens.V4720[(jovens.V4720 < 2000)]
jovens.V4720.plot(kind='hist')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
jovens.V4720 = jovens.V4720[(jovens.V4720 > 0)]
jovens.V4720.plot(kind='hist')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
media = jovens.V8005.mean()
print((1/media)*100)
# Out:
# 7.338236685993083

# %%
jovens = dados[(dados.V8005 >= 10) & (dados.V8005 <= 17) & (dados.V4720 < 99999999)]
np.average(jovens.V4720)
# Out:
# 61.730247555648013

# %% [markdown]
# # Adultos

# %%
coluna = adultos.V9057
coluna = coluna.astype('category')
coluna.cat.categories = ('Até 30 minutos','Entre 30mins e 1hora', " Entre 1 hora até 2 horas","Mais de duas horas")
colum = adultos.V9057
coluna = coluna.value_counts(True)*100
coluna.plot(kind="pie",colors=("blue","green","red","yellow"))

# %%
colum.value_counts()
# Out:
# 1.0    30203
# 3.0    11361
# 5.0     4117
# 7.0      934
# Name: V9057, dtype: int64

# %%
horas_Caminho = ((51685*0.5+19565*0.75 + 7039*1.5 + 1589*2)/(51685+19565+7039+1589))*2
print(((51685*0.5+19565*0.75 + 7039*1.5 + 1589*2)/(51685+19565+7039+1589))*2)
# Out:
# 1.3583902952001803

# %%
adultos.V9058 = adultos.V9058/7
adultos.V9058.plot(kind='box')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
adultos.V9058 = adultos.V9058[(adultos.V9058 > 4) & (adultos.V9058 < 12)]
adultos.V9058.plot(kind='box')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
adultos.V9058.plot(kind='hist',normed=1)

# %%
horas_trabalhadas= 8
adultos.V9058.mean()
# Out:
# 6.193762196352538

# %%
adultos.V9921 = adultos.V9921/7
adultos.V9921.plot(kind='box')
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
adultos.V9921.plot(kind='hist')

# %%
horas_afazeres = 2.9
adultos.V9921.mean()
# Out:
# 2.982671609573329

# %%
tempo_livre = 18 - horas_afazeres - horas_trabalhadas - horas_Caminho
print(tempo_livre)
# Out:
# 5.741609704799819

# %%
adultos = dados[(dados.V8005 >= 35)  & (dados.V8005 < 50)]

# %%
adultos.V4720 = adultos.V4720[(adultos.V4720 >0) & (adultos.V4720 < 10000)]
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
adultos.V4720.plot(kind='box')

# %%
adultos.V4720.value_counts()
# Out:
# 724.0     6689
# 1000.0    3186
# 1200.0    3069
# 2000.0    2947
# 1500.0    2728
# 800.0     2178
# 3000.0    1790
# 900.0     1571
# 2500.0    1415
# 1400.0    1231
# 1300.0    1179
# 1100.0    1091
# 1800.0    1050
# 4000.0     985
# 5000.0     980
# 500.0      904
# 1600.0     805
# 600.0      782
# 400.0      701
# 3500.0     701
# 300.0      699
# 700.0      631
# 1448.0     549
# 850.0      507
# 200.0      485
# 1700.0     481
# 2200.0     445
# 6000.0     416
# 2100.0     383
# 112.0      359
#           ...
# 2362.0       1
# 2364.0       1
# 607.0        1
# 2282.0       1
# 2275.0       1
# 2273.0       1
# 2230.0       1
# 2212.0       1
# 661.0        1
# 1281.0       1
# 9970.0       1
# 658.0        1
# 657.0        1
# 2222.0       1
# 2226.0       1
# 653.0        1
# 652.0        1
# 649.0        1
# 2268.0       1
# 648.0        1
# 2237.0       1
# 2238.0       1
# 2239.0       1
# 2242.0       1
# 643.0        1
# 2243.0       1
# 641.0        1
# 2245.0       1
# 636.0        1
# 1137.0       1
# Name: V4720, dtype: int64

# %%
adultos.V4720.plot(kind='hist')

# %%
media = adultos.V8005.mean()
print((1/media)*100)
# Out:
# 2.396089340890053

# %%
adultos = dados[(dados.V8005 >= 26)  & (dados.V8005 < 50)]
adultos.V4720 = adultos.V4720[(adultos.V4720 >0) & (adultos.V4720 < 99999999)]
adultos.V4720.mean()
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\pandas\core\generic.py:2701: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# 1731.2515918504737
